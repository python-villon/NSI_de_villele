# %% [markdown]
# # I introduction

# %%
import graphviz as gv
                  
G = gv.Digraph()

G.attr(root = 'root', size = '15', engine = 'dot')          

G.node_attr.update( style = 'filled',   
                    shape = 'circle',     
                    fontsize = '11', 
                    width = '0.3',       
                    height = '0.3',      
                    #fixedsize = 'False',
                    margin = '0, 0')   

G.edge_attr.update( style = 'solid',       
                    arrowsize = '0.5')

# %%
G.node('0', label = 'A')

G.node('00', label = 'B')
G.node('01', label = 'C')
G.node('02', label = 'D')
G.edge('0', '00')
G.edge('0', '01')
G.edge('0', '02')

G.node('000', label = 'E')
G.node('001', label = 'F')
G.edge('00', '000')
G.edge('00', '001')


G.node('010', label = 'G')
G.node('011', label = 'H')
G.node('012', label = 'I')
G.edge('01', '010')
G.edge('01', '011')
G.edge('01', '012')


G.node('020', label = 'J')
G.edge('02', '020')

G.node('0000', label = 'K')
G.node('0001', label = 'L')
G.node('0002', label = 'M')
G.edge('000', '0000')
G.edge('000', '0001')
G.edge('000', '0002')


G.node('0110', label = 'N')
G.node('0111', label = 'O')
G.edge('011', '0110')
G.edge('011', '0111')


G.node('0120', label = 'P')
G.edge('012', '0120')

G.node('01200', label = 'Q')
G.edge('0120', '01200')

display(G)

# %%
import graphviz as gv
                  
G = gv.Digraph()

G.attr(root = 'root', size = '15', engine = 'dot')          

G.node_attr.update( style = 'filled',   
                    shape = 'circle',     
                    fontsize = '11', 
                    width = '0.3',       
                    height = '0.3',      
                    #fixedsize = 'False',
                    margin = '0, 0')   

G.edge_attr.update( style = 'solid',       
                    arrowsize = '0.5')

# %%
G.node('0', label = 'A')

G.node('00', label = 'B')#, penwidth = '0', color = 'white')
G.node('01', label = 'C')#, penwidth = '0', color = 'white')
G.node('02', label = 'D')#, penwidth = '0', color = 'white')
G.edge('0', '00')
G.edge('0', '01')
G.edge('0', '02')

display(G)

# %%
import graphviz as gv
                  
G = gv.Digraph()

G.attr(root = 'root', size = '15', engine = 'dot')          

G.node_attr.update( style = 'filled',   
                    shape = 'circle',     
                    fontsize = '11', 
                    width = '0.3',       
                    height = '0.3',      
                    #fixedsize = 'False',
                    margin = '0, 0')   

G.edge_attr.update( style = 'solid',       
                    arrowsize = '0.5')

# %%
G.node('0', label = 'A')

G.node('00', label = 'B', color = 'pink')
G.node('01', label = 'C', color = 'yellow')
G.node('02', label = 'D', color = 'turquoise')
G.edge('0', '00')
G.edge('0', '01')
G.edge('0', '02')

G.node('000', label = 'E', color = 'pink')
G.node('001', label = 'F', color = 'pink')
G.edge('00', '000')
G.edge('00', '001')


G.node('010', label = 'G', color = 'yellow')
G.node('011', label = 'H', color = 'yellow')
G.node('012', label = 'I', color = 'yellow')
G.edge('01', '010')
G.edge('01', '011')
G.edge('01', '012')


G.node('020', label = 'J', color = 'turquoise')
G.edge('02', '020')

G.node('0000', label = 'K', color = 'pink')
G.node('0001', label = 'L', color = 'pink')
G.node('0002', label = 'M', color = 'pink')
G.edge('000', '0000')
G.edge('000', '0001')
G.edge('000', '0002')


G.node('0110', label = 'N', color = 'yellow')
G.node('0111', label = 'O', color = 'yellow')
G.edge('011', '0110')
G.edge('011', '0111')


G.node('0120', label = 'P', color = 'yellow')
G.edge('012', '0120')

G.node('01200', label = 'Q', color = 'yellow')
G.edge('0120', '01200')






display(G)

# %%
import graphviz as gv
                  
G = gv.Digraph()

G.attr(root = 'root', size = '15', engine = 'dot')          

G.node_attr.update( style = 'filled',   
                    shape = 'circle',     
                    fontsize = '11', 
                    width = '0.3',       
                    height = '0.3',      
                    #fixedsize = 'False',
                    margin = '0, 0')   

G.edge_attr.update( style = 'solid',       
                    arrowsize = '0.5')

# %%
G.node('0', label = 'A')

G.node('00', label = 'B')
G.node('01', label = 'C')
G.node('02', label = 'D')
G.edge('0', '00')
G.edge('0', '01')
G.edge('0', '02')

G.node('000', label = 'E')
G.node('001', label = 'F', color = 'lightgreen')
G.edge('00', '000')
G.edge('00', '001')


G.node('010', label = 'G', color = 'lightgreen')
G.node('011', label = 'H')
G.node('012', label = 'I')
G.edge('01', '010')
G.edge('01', '011')
G.edge('01', '012')


G.node('020', label = 'J', color = 'lightgreen')
G.edge('02', '020')

G.node('0000', label = 'K', color = 'lightgreen')
G.node('0001', label = 'L', color = 'lightgreen')
G.node('0002', label = 'M', color = 'lightgreen')
G.edge('000', '0000')
G.edge('000', '0001')
G.edge('000', '0002')


G.node('0110', label = 'N', color = 'lightgreen')
G.node('0111', label = 'O', color = 'lightgreen')
G.edge('011', '0110')
G.edge('011', '0111')


G.node('0120', label = 'P')
G.edge('012', '0120')

G.node('01200', label = 'Q', color = 'lightgreen')
G.edge('0120', '01200')






display(G)

# %% [markdown]
# # II : Arbres binaires

# %%
import graphviz as gv
                  
G = gv.Digraph()

G.attr(root = 'root', size = '15', engine = 'dot')          

G.node_attr.update( style = 'filled',   
                    shape = 'circle',     
                    fontsize = '11', 
                    width = '0.3',       
                    height = '0.3',      
                    #fixedsize = 'False',
                    margin = '0, 0')   

G.edge_attr.update( style = 'solid',       
                    arrowsize = '0.5',
                    arrowhead = 'none')

# %%
G.node('0', label = 'A')

G.node('00', label = 'B')
G.node('01', label = 'C')
G.edge('0', '00')
G.edge('0', '01')

G.node('000', label = 'D')
G.node('001', label = 'E')
G.edge('00', '000')
G.edge('00', '001')


G.node('011', label = 'F')
G.edge('01', '011')


G.node('0001', label = 'G')
G.edge('000', '0001')


G.node('0110', label = 'H')
G.node('0111', label = 'I')
G.edge('011', '0110')
G.edge('0110', '0111')


G.node('01100', label = 'J')
G.edge('0110', '01100')



display(G)

# %%
import graphviz as gv
                  
G = gv.Digraph()

G.attr(root = 'root', size = '15', engine = 'dot')          

G.node_attr.update( style = 'filled',   
                    shape = 'circle',     
                    fontsize = '11', 
                    width = '0.3',       
                    height = '0.3',      
                    #fixedsize = 'False',
                    margin = '0, 0')   

G.edge_attr.update( style = 'solid',
                    arrowhead = 'none',
                    arrowsize = '0.5')

# %%
G.node('0', label = 'A')

G.node('00', label = 'B')
G.node('01', label = 'C')
G.edge('0', '00')
G.edge('0', '01')

G.node('000', label = 'D')
G.node('001', label = 'E')
G.edge('00', '000')
G.edge('00', '001')
G.node('E0', label = '*', penwidth = '0', color = 'white')
G.node('E1', label = '*', penwidth = '0', color = 'white')
G.edge('001', 'E0')
G.edge('001', 'E1')

G.node('010', label = '*', penwidth = '0', color = 'white')
G.node('011', label = 'F')
G.edge('01', '010')
G.edge('01', '011')


G.node('0000', label = '*', penwidth = '0', color = 'white')
G.node('0001', label = 'G')
G.edge('000', '0000')
G.edge('000', '0001')
G.node('I0', label = '*', penwidth = '0', color = 'white')
G.node('I1', label = '*', penwidth = '0', color = 'white')
G.edge('0001', 'I0')
G.edge('0001', 'I1')



G.node('0110', label = 'H')
G.node('0111', label = '*', penwidth = '0', color = 'white')
G.edge('011', '0110')
G.edge('011', '0111')


G.node('01100', label = 'I')
G.node('01101', label = 'J')
G.edge('0110', '01100')
G.edge('0110', '01101')
G.node('L0', label = '*', penwidth = '0', color = 'white')
G.node('L1', label = '*', penwidth = '0', color = 'white')
G.edge('01100', 'L0')
G.edge('01100', 'L1')
G.node('M0', label = '*', penwidth = '0', color = 'white')
G.node('M1', label = '*', penwidth = '0', color = 'white')
G.edge('01101', 'M0')
G.edge('01101', 'M1')

display(G)

# %%
import graphviz as gv
                  
G = gv.Digraph()

G.attr(root = 'root', size = '15', engine = 'dot')          

G.node_attr.update( style = 'filled',   
                    shape = 'circle',     
                    fontsize = '11', 
                    width = '0.3',       
                    height = '0.3',      
                    #fixedsize = 'False',
                    margin = '0, 0')   

G.edge_attr.update( style = 'solid',
                    arrowhead = 'none',
                    arrowsize = '0.5')

# %%
G.node('0', label = 'A')

G.node('00', label = 'B')
G.node('01', label = 'C')
G.edge('0', '00')
G.edge('0', '01')

G.node('000', label = 'D')
G.node('001', label = 'E')
G.edge('00', '000')
G.edge('00', '001')
G.node('E0', label = ' ', penwidth = '0', color = 'white')
G.node('E1', label = ' ', penwidth = '0', color = 'white')
G.edge('001', 'E0')
G.edge('001', 'E1')

G.node('010', label = ' ', penwidth = '0', color = 'white')
G.node('011', label = 'F')
G.edge('01', '010')
G.edge('01', '011')


G.node('0000', label = ' ', penwidth = '0', color = 'white')
G.node('0001', label = 'G')
G.edge('000', '0000')
G.edge('000', '0001')
G.node('I0', label = ' ', penwidth = '0', color = 'white')
G.node('I1', label = ' ', penwidth = '0', color = 'white')
G.edge('0001', 'I0')
G.edge('0001', 'I1')



G.node('0110', label = 'H')
G.node('0111', label = ' ', penwidth = '0', color = 'white')
G.edge('011', '0110')
G.edge('011', '0111')


G.node('01100', label = 'I')
G.node('01101', label = 'J')
G.edge('0110', '01100')
G.edge('0110', '01101')
G.node('L0', label = ' ', penwidth = '0', color = 'white')
G.node('L1', label = ' ', penwidth = '0', color = 'white')
G.edge('01100', 'L0')
G.edge('01100', 'L1')
G.node('M0', label = ' ', penwidth = '0', color = 'white')
G.node('M1', label = ' ', penwidth = '0', color = 'white')
G.edge('01101', 'M0')
G.edge('01101', 'M1')

display(G)

# %%
import graphviz as gv
                  
G = gv.Digraph()

G.attr(root = 'root', size = '15', engine = 'dot')          

G.node_attr.update( style = 'filled',   
                    shape = 'circle',     
                    fontsize = '11', 
                    width = '0.3',       
                    height = '0.3',      
                    #fixedsize = 'False',
                    margin = '0, 0')   

G.edge_attr.update( style = 'solid',       
                    arrowsize = '0.5',
                    arrowhead = 'none')

# %%
G.node('0', label = 'A')

G.node('00', label = 'B')
G.node('01', label = 'C')
G.edge('0', '00')
G.edge('0', '01')

G.node('000', label = 'D')
G.node('001', label = 'E', color = 'lightgreen')
G.edge('00', '000')
G.edge('00', '001')
G.node('E0', label = '*', penwidth = '0', color = 'white')
G.node('E1', label = '*', penwidth = '0', color = 'white')
G.edge('001', 'E0')
G.edge('001', 'E1')

G.node('010', label = '*', penwidth = '0', color = 'white')
G.node('011', label = 'F')
G.edge('01', '010')
G.edge('01', '011')


G.node('0000', label = '*', penwidth = '0', color = 'white')
G.node('0001', label = 'G', color = 'lightgreen')
G.edge('000', '0000')
G.edge('000', '0001')
G.node('I0', label = '*', penwidth = '0', color = 'white')
G.node('I1', label = '*', penwidth = '0', color = 'white')
G.edge('0001', 'I0')
G.edge('0001', 'I1')



G.node('0110', label = 'H')
G.node('0111', label = '*', penwidth = '0', color = 'white')
G.edge('011', '0110')
G.edge('011', '0111')


G.node('01100', label = 'I', color = 'lightgreen')
G.node('01101', label = 'J', color = 'lightgreen')
G.edge('0110', '01100')
G.edge('0110', '01101')
G.node('L0', label = '*', penwidth = '0', color = 'white')
G.node('L1', label = '*', penwidth = '0', color = 'white')
G.edge('01100', 'L0')
G.edge('01100', 'L1')
G.node('M0', label = '*', penwidth = '0', color = 'white')
G.node('M1', label = '*', penwidth = '0', color = 'white')
G.edge('01101', 'M0')
G.edge('01101', 'M1')

display(G)

# %%
import graphviz as gv
                  
G = gv.Digraph()

G.attr(root = 'root', size = '15', engine = 'dot')          

G.node_attr.update( style = 'filled',   
                    shape = 'circle',     
                    fontsize = '11', 
                    width = '0.3',       
                    height = '0.3',      
                    #fixedsize = 'False',
                    margin = '0, 0')   

G.edge_attr.update( style = 'solid',       
                    arrowsize = '0.5',
                    arrowhead = 'none')

# %%
G.node('0', label = '')

G.node('00', label = '', penwidth = '0', color = 'white', width = '1')
G.node('01', label = '', penwidth = '0', color = 'white', width = '1')
G.edge('0', '00')
G.edge('0', '01')

display(G)

# %%
import graphviz as gv
                  
G = gv.Digraph()

G.attr(root = 'root', size = '15', engine = 'dot')          

G.node_attr.update( style = 'filled',   
                    shape = 'circle',     
                    fontsize = '11', 
                    width = '0.3',       
                    height = '0.3',      
                    #fixedsize = 'False',
                    margin = '0, 0')   

G.edge_attr.update( style = 'solid',       
                    arrowsize = '0.5',
                    arrowhead = 'none')

# %%
G.node('0', label = '7')

G.node('00', label = '', penwidth = '0', color = 'white')
G.node('01', label = '13')
G.edge('0', '00')
G.edge('0', '01')

G.node('010', label = '1')
G.node('011', label = '2')
G.edge('01', '010')
G.edge('01', '011')

G.node('0100', label = ' ', penwidth = '0', color = 'white')
G.node('0101', label = ' ', penwidth = '0', color = 'white')
G.edge('010', '0100')
G.edge('010', '0101')

G.node('0110', label = ' ', penwidth = '0', color = 'white')
G.node('0111', label = ' ', penwidth = '0', color = 'white'
      )
G.edge('011', '0110')
G.edge('011', '0111')

display(G)

# %% [markdown]
# # -------

# %% [markdown]
# # Exercices

# %%
import graphviz as gv
                  
G = gv.Digraph()

G.attr(root = 'root', size = '15', engine = 'dot')          

G.node_attr.update( style = 'filled',   
                    shape = 'circle',     
                    fontsize = '11', 
                    width = '0.3',       
                    height = '0.3',      
                    #fixedsize = 'False',
                    margin = '0, 0')   

G.edge_attr.update( style = 'solid',       
                    arrowsize = '0.5')

# %%
G.node('0', label = 'A')

G.node('00', label = 'B')
G.node('01', label = 'C')
G.node('03', label = 'D')
G.node('02', label = 'E')

G.edge('0', '00')
G.edge('0', '01')
G.edge('0', '03')
G.edge('0', '02')


G.node('000', label = 'F')
G.node('001', label = 'G')
G.edge('00', '000')
G.edge('00', '001')


G.node('010', label = 'H')
G.node('011', label = 'I')
G.node('012', label = 'J')
G.edge('01', '010')
G.edge('01', '011')
G.edge('01', '012')

G.node('021', label = 'K')
G.edge('02', '021')
G.node('020', label = 'L')
G.edge('02', '020')

G.node('0000', label = 'M')
G.node('0002', label = 'N')
G.edge('000', '0000')
G.edge('000', '0002')


G.node('0110', label = 'O')
G.edge('011', '0110')



G.node('0120', label = 'P')
G.edge('012', '0120')

G.node('0200', label = 'Q')
G.edge('020', '0200')

G.node('00020', label = 'R')
G.edge('0002', '00020')






display(G)
