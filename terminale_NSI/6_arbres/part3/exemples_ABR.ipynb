# %%
from arbres_binaires import*


n = Noeud(100, 
          Noeud(10, 
                Noeud(3,
                      None, 
                      Noeud(7, None, None)),
                Noeud(50, 
                      Noeud(20, None, None),
                      Noeud(95, None, None))),
          Noeud(1000,
                Noeud(500, 
                      Noeud(300, None, None),
                      Noeud(800, None, None)),
                Noeud(5000, 
                      Noeud(1001, None, None),
                      Noeud(9998,
                            None, 
                            Noeud(9999, None, None)))))
schema(n)

# %%
from arbres_binaires import*


n = Noeud(23,
          Noeud(16, 
                Noeud(10, None, None), 
                Noeud(18, None, None)),
          Noeud(29, None, None))
schema(n)

# %%
from arbres_binaires import*


# FAKE

n = Noeud(31,
          Noeud(8, 
                Noeud(6, None, None), 
                Noeud(7, 
                      None, 
                      Noeud(12, None, None))),
          Noeud(85,
                Noeud(64, None, None), 
                None))
schema(n)

# %%
from arbres_binaires import*


# FAKE

n = Noeud(31,
          Noeud(8, 
                Noeud(6, None, None), 
                Noeud(12, 
                      None, 
                      Noeud(32, None, None))),
          Noeud(85,
                Noeud(64, None, None), 
                None))
schema(n)

# %%
from arbres_binaires import*


# OK

n = Noeud(31,
          Noeud(8, 
                Noeud(6, None, None), 
                Noeud(10, 
                      None, 
                      Noeud(12, None, None))),
          Noeud(85,
                Noeud(64, None, None), 
                None))
schema(n)

# %%
from arbres_binaires import*

# Voir au dessus

n = Noeud(31,
          Noeud(8, 
                Noeud(6, None, None), 
                None),
          Noeud(85,
                Noeud(64,
                      Noeud(62, 
                            None, 
                            Noeud(63, None, None)),
                      None), 
                None))
schema(n)

# %%
from arbres_binaires import*

# Voir au dessus

n = Noeud(31,
          Noeud(8, 
                Noeud(6, None, None), 
                None),
          Noeud(85,
                None,
                Noeud(93,
                      Noeud(86, 
                            None, 
                            Noeud(87, None, None)),
                      Noeud(94, 
                            None, 
                            Noeud(95, None, None)))))
schema(n)

# %%
from arbres_binaires import*


# OK

n = Noeud('map',
          Noeud('chr', 
                Noeud('bin', None, None), 
                Noeud('hex', 
                      None, 
                      Noeud('len', None, None))),
          Noeud('str',
                Noeud('max', 
                      Noeud('min', None, None),
                      None),
                None))
schema(n)

# %%
from arbres_binaires import*


n = Noeud(23,
          Noeud(21, 
                Noeud(14, 
                      Noeud(7, None, None),
                      None),
                None),
          None)
schema(n)

# %%
from arbres_binaires import*

# FAKE

n = Noeud(23,
          None,
          Noeud(51,
                None,
                Noeud(73,
                      None,
                      Noeud(71, None, None))))
schema(n)
